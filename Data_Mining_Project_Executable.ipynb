# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Data Mining/Project/Code
# Out:
# /content/drive/MyDrive/Data Mining/Project/Code

# %% [markdown]
# **Step 1: Pre-processing**

# %%
# %%bash
#
# javac -cp "lib/*" -d bin src/Main.java
#
#
# if [ $? -ne 0 ]; then
#     echo "Compile failed."
#     # The script will stop here. 'pause' and 'exit /b 1' are Windows-specific.
#     exit 1
# fi
#
# # --- Run ---
# echo "Running Java application..."
# java --add-opens java.base/java.lang=ALL-UNNAMED \
#      --add-opens java.base/java.lang.reflect=ALL-UNNAMED \
#      -cp "bin:lib/*" src.Main 1
# Out:
# Running Java application...
# === DATA MINING PIPELINE START ===
# Running steps: [1]
#
# --- STEP 1: Preprocessing and Data Analysis ---
# Loading CSV: data/World Happiness Report 2024.csv
# Loaded: 2363 instances, 11 attributes.
# No completely empty attributes found.
# No duplicate instances found.
# Winsorizing numeric attributes with IQR 1.5 rule...
#  - Attr 'Life Ladder': lower=2.1289 upper=8.8427 clipped=2
#  - Attr 'Log GDP per capita': lower=5.6742 upper=13.2250 clipped=1
#  - Attr 'Social support': lower=0.5037 upper=1.1439 clipped=49
#  - Attr 'Healthy life expectancy at birth': lower=45.1263 upper=82.6162 clipped=20
#  - Attr 'Freedom to make life choices': lower=0.3590 upper=1.1634 clipped=16
#  - Attr 'Generosity': lower=-0.4205 upper=0.4021 clipped=39
#  - Attr 'Perceptions of corruption': lower=0.4154 upper=1.1390 clipped=194
#  - Attr 'Positive affect': lower=0.3236 upper=0.9856 clipped=8
#  - Attr 'Negative affect': lower=0.0320 upper=0.5028 clipped=29
# ...

# %% [markdown]
# **Step 2: Implement a classification algorithm: RandomForest**

# %%
# %%bash
#
# javac -cp "lib/*" -d bin src/Main.java
#
#
# if [ $? -ne 0 ]; then
#     echo "Compile failed."
#     # The script will stop here. 'pause' and 'exit /b 1' are Windows-specific.
#     exit 1
# fi
#
# # --- Run ---
# echo "Running Java application..."
# java --add-opens java.base/java.lang=ALL-UNNAMED \
#      --add-opens java.base/java.lang.reflect=ALL-UNNAMED \
#      -cp "bin:lib/*" src.Main 2
# Out:
# Running Java application...
# === DATA MINING PIPELINE START ===
# Running steps: [2]
#
# --- STEP 2: RandomForest (Algorithm A) ---
# Loading preprocessed data from: data/world_happiness_cleaned.arff
# Standardized copy created for algorithms that require scaling.
# RandomForest (10-fold CV) results:
#
# Correctly Classified Instances        1985               84.0034 %
# Incorrectly Classified Instances       378               15.9966 %
# Kappa statistic                          0.76
# Mean absolute error                      0.1415
# Root mean squared error                  0.2767
# Relative absolute error                 31.8345 %
# Root relative squared error             58.6926 %
# Total Number of Instances             2363
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
#                  0.854    0.063    0.869      0.854    0.862      0.794    0.967     0.929     Low
# ...

# %% [markdown]
# **Step 2's Visualization**

# %%
import os
from IPython.display import Image, display

for i in range(1, 9):
    display(Image(os.path.join('img/a', f"{i}.png")))

# %% [markdown]
# **Step 3: Implement another classification algorithm: J48 And Add Cluster as Predictor**

# %%
# %%bash
#
# javac -cp "lib/*" -d bin src/Main.java
#
#
# if [ $? -ne 0 ]; then
#     echo "Compile failed."
#     # The script will stop here. 'pause' and 'exit /b 1' are Windows-specific.
#     exit 1
# fi
#
# # --- Run ---
# echo "Running Java application..."
# java --add-opens java.base/java.lang=ALL-UNNAMED \
#      --add-opens java.base/java.lang.reflect=ALL-UNNAMED \
#      -cp "bin:lib/*" src.Main 3
# Out:
# Running Java application...
# === DATA MINING PIPELINE START ===
# Running steps: [3]
#
# --- STEP 3: J48 (Algorithm B) with AddCluster (SimpleKMeans) ---
# Loading preprocessed data from: data/world_happiness_cleaned.arff
# Added cluster id attribute (k=6).
# Set class to 'happiness_level' (index 11).
# [Visual saved] /content/drive/MyDrive/Data Mining/Project/Code/clusters_from_addcluster.png
# J48 (+ AddCluster And 10-fold CV) results:
#
# Correctly Classified Instances        1851               78.3326 %
# Incorrectly Classified Instances       512               21.6674 %
# Kappa statistic                          0.675
# Mean absolute error                      0.197
# Root mean squared error                  0.3366
# Relative absolute error                 44.3197 %
# Root relative squared error             71.3991 %
# Total Number of Instances             2363
#
# === Detailed Accuracy By Class ===
#
# ...

# %% [markdown]
# **Step 3's Visualization**

# %%
import os
from IPython.display import Image, display

for i in range(1, 9):
    display(Image(os.path.join('img/b', f"{i}.png")))

# %% [markdown]
# **Step 4: Model Evaluation**

# %%
# %%bash
#
# javac -cp "lib/*" -d bin src/Main.java
#
#
# if [ $? -ne 0 ]; then
#     echo "Compile failed."
#     # The script will stop here. 'pause' and 'exit /b 1' are Windows-specific.
#     exit 1
# fi
#
# # --- Run ---
# echo "Running Java application..."
# java --add-opens java.base/java.lang=ALL-UNNAMED \
#      --add-opens java.base/java.lang.reflect=ALL-UNNAMED \
#      -cp "bin:lib/*" src.Main 4
# Out:
# Running Java application...
# === DATA MINING PIPELINE START ===
# Running steps: [4]
#
# --- STEP 4: Comparison and Detailed Evaluation ---
# ...
#
# --- STEP 2: RandomForest (Algorithm A) ---
# Loading preprocessed data from: data/world_happiness_cleaned.arff
# Standardized copy created for algorithms that require scaling.
# RandomForest (10-fold CV) results:
#
# Correctly Classified Instances        1985               84.0034 %
# Incorrectly Classified Instances       378               15.9966 %
# Kappa statistic                          0.76
# Mean absolute error                      0.1415
# Root mean squared error                  0.2767
# Relative absolute error                 31.8345 %
# Root relative squared error             58.6926 %
# Total Number of Instances             2363
#
# === Detailed Accuracy By Class ===
#
#                  TP Rate  FP Rate  Precision  Recall   F-Measure  MCC      ROC Area  PRC Area  Class
# ...
